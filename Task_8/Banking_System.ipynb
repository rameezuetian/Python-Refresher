# %% [markdown]
# # OOP: Foundations:
#
# Concepts:
#
# ● Defining classes, creating objects, `__init__()`, `self`
#
# ● Instance attributes vs class attributes
#
# ● Instance methods, `@classmethod`, `@staticmethod`
#
# ● `public`, `_protected`, `__private` naming conventions
#
# ● `@property` and `@setter` for controlled access
#
# ● `__str__()` and `__repr__()` for readable output

# %% [markdown]
# - Task:
#
# ● Banking System: Build a `BankAccount` class that stores an owner name and balance
# securely. The balance must be inaccessible from outside the class. Deposits and
# withdrawals go through validated methods only. Print any account and get a clean,
# readable summary.

# %%
class BankAccount:

    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):

        if amount > 0:
            self.__balance += amount
        else:
            print("Invalid deposit")

    def withdraw(self, amount):

        if amount > self.__balance:
            print("Insufficient funds")
        else:
            self.__balance -= amount

    def __str__(self):
        return f"Owner: {self.owner}, Balance: {self.__balance}"


account1 = BankAccount("Ali", 1000)

account1.deposit(500)
account1.withdraw(200)

print(account1)
# Out:
# Owner: Ali, Balance: 1300
